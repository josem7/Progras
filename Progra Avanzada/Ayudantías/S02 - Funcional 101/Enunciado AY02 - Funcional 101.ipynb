# %% [markdown]
# # Ayudantía 02
#
# ## Programación Funcional
#
# Vicente Águila y Paul Heinsohn
#
# **Form de Feedback:** https://docs.google.com/forms/d/1rublnCunwYWYe2QxARiND1hS9WJ9jKLE6WJilA7rRvE
#
# ## ¿Por qué?
#
# * Existen lenguajes de programación que utilizan este paradigma (Erlang)
# * Procesamiento de información optimizada
#
# ________________________________________________________________________________
#
# ## Introducción
# <br>
# <div style="text-align: justify">
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Llevas todo el día estudiando la materia de Programación funcional que ya no das más, por lo que decides ver <strike>muchas</strike> una película, sin embargo, hay tantas películas buenas como ’Buscando a Enzo’, ’Las 50 Sombras de Hernan’, ’Lo Que Benja Se Llevó', etc. que no logras decidirte. Luego de un rato, llegas a la brillante idea de crear un programa que te ayude a resolverlo, para esto ingresas a Prograflix a ver como puedes comenzar.
#
# <img src="img/prograflix.png">
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;El objetivo es realizar un sistema de consultas que te permita obtener información sobre películas y actores. Para esto, obtienes mágicamente la base de datos de <i>Prograflix</i> organizada en dos archivos especificados a continuación:
#
# <ul>
#     <li><b>peliculas.txt:</b> Archivo de texto que contiene la información de las películas que puedes ver, de la forma: `id, nombre, puntuacion, fecha_estreno, genero`.</li><br>
#     <li><b>actores.txt:</b> Archivo de texto que alberga la información de los artistas que trabajaron en las películas. Está distribuido de la forma: `nombre_pelicula, nombre_actor, nombre_personaje`.</li>
# </ul>
#
# Con esta información debes ser capaz de resolver las consultas especificadas siempre y cuando se cumpla lo siguiente:
#
# <ul>
#     <li>Tu solución debe ser realizada con <b>programación funcional</b></li><br>
#     <li>Quieres que tu programa no almacene el archivo en memoria, ergo, la lectura tendrá que ser sólamente mediante el uso de generadores</li><br>
#     <li>Cada película debe tener su propio id que debe estar implementado con <b>generadores</b>. El id es distinto al que trae la base de datos, para que puedas distinguirla con tu programa.</li><br>
# </ul>
#
# Luego, lo primero que debemos hacer es crear el id para las películas:
# </div>

# %%
def generador_id():
    n=0
    while True:
        yield n
        n+=1

# %% [markdown]
# Procedemos a definir las películas y los actores:

# %%
from collections import namedtuple

Pelicula = namedtuple("Pelicula",["id", "nombre", "puntuacion", "fecha_estreno", "genero"])
Actores = namedtuple("Actor",["nombre_pelicula","nombre_actor","personaje"])

# %% [markdown]
# <div style="text-align: justify">Ahora faltaría abrir los archivos para instanciar los actores y las películas. Hasta ahora solo hemos trabajado los archivos guardándolos en memoria mediante "for's" tediosos... pero qué tal si lo hacemos con listas por compresión:
# </div>

# %%
limpeador = lambda linea: linea.strip().split(",")
gen_id = generador_id()
with open("archivos/peliculas.txt", "r" , encoding = "utf8") as archivo:
    PELICULAS = [Pelicula(next(gen_id), *limpeador(linea)[1:]) for linea in archivo]

with open("archivos/actores.txt", "r" , encoding = "utf8") as archivo:
    ACTORES = [Actores(*limpeador(linea))for linea in archivo]

# %% [markdown]
# ________________________________________________________________________________
# Dentro de las consultas que nuestro programa debe soportar veremos los siguientes:
#
# * Crear el método <b>popular</b> que dado un número <b>n</b>, retorne todas las películas que tienen un rating superior a dicho valor.

# %%
def popular(peli, n):
    return filter(lambda p: float(p.puntuacion) >= (n), peli)

# %%
print([top.nombre for top in popular(PELICULAS, 20)])
# Out:
# ['Fantastic Beasts and Where to Find Them', 'Doctor Strange', 'Kong: Skull Island', 'Arrival', 'Guardians of the Galaxy', 'Rings', 'Split', 'John Wick', 'Mad Max: Fury Road', 'Jurassic World', 'Logan', 'Fifty Shades Darker', 'Beauty and the Beast', 'Captain America: Civil War', 'Interstellar', "Assassin's Creed"]

# %% [markdown]
# ________________________________________________________________________________
# * Cree la función **actores_genero** que retorne el **nombre** de todos los actores que actuaron en una película del **género** especificado.

# %%
def actores_genero(gen, l_actores, l_peliculas):
    lista_generos_peli = filter(lambda p: p.genero == gen, l_peliculas)
    nombre_genero = list(map(lambda a: a.nombre, lista_generos_peli))
    
    actores_peli = filter(lambda a: a.nombre_pelicula in nombre_genero, l_actores)
    return map(lambda a: a.nombre_actor, actores_peli)
actores_genero("Comedy", ACTORES, PELICULAS)

# %%
print(*list(actores_genero("Comedy", ACTORES, PELICULAS))[:10], sep="\n")
# Out:
# Kaley Cuoco
# Zoey Deutch
# Jessica Barth
# Stephen Root
# Blake Jenner
# Jennifer Aniston
# Courtney B. Vance
# Seth MacFarlane
# Megan Mullally
# Lewis Black

# %% [markdown]
# ________________________________________________________________________________
# * Crear el método <b>puntuacion_actor</b> que dado el <b>nombre de 'Hugh Jackman'</b>, retorna el promedio de la puntuación de las películas en las que ha participado.

# %%
from functools import reduce

def puntuacion_actor(l_peli, l_actores, n_actor):
    peli_actua = filter(lambda a: a.nombre_actor == n_actor, l_actores)
    nombre_plei = list(map(lambda a: a.nombre_pelicula, peli_actua))
    
    t_peli = filter(lambda p: p.nombre in nombre_plei, l_peli )
    l_punt = list(map(lambda p: p.puntuacion, t_peli))
    return float(reduce(lambda x, y: float(x) + float(y), l_punt)) / len(l_punt)
    
    
puntuacion_actor(PELICULAS, ACTORES, "Hugh Jackman")
# Out:
# 58.03259566666666

# %%
print("Hugh Jackman's rating: {}".format(puntuacion_actor(PELICULAS, ACTORES, "Hugh Jackman")))
# Out:
# Hugh Jackman's rating: 58.03259566666666

# %% [markdown]
# * Crear el método **puntuaciones_actores** que retorne el promedio de la puntuación de las películas en que cada actor ejerce su trabajo.

# %%
def puntuaciones_actores(l_peli, l_actores):
    list_nombre = list(map(lambda x: x.nombre_actor, l_actores))
    list_puntuacion = list(map(lambda x: puntuacion_actor(l_peli, l_actores, x),list_nombre))
    return list(zip (list_nombre,list_puntuacion))

# %%
puntuaciones_actores(PELICULAS, ACTORES)
# Out:
# [('Dafne Keen', 157.275668),
#  ('Sandra Bullock', 11.594164),
#  ('Allison Janney', 11.07952225),
#  ('Brad Garrett', 7.642378),
#  ('Allison Janney', 11.07952225),
#  ('Mark Wahlberg', 7.2816855),
#  ('Hugh Jackman', 58.03259566666666),
#  ('Kaley Cuoco', 16.928488),
#  ('Aldis Hodge', 8.192746),
#  ('Jason Clarke', 10.2978015),
#  ('Kevin Spacey', 5.697074),
#  ('Symara A. Templeman', 5.887713),
#  ('Natalie Portman', 7.4017905),
#  ('Michele Valley', 5.872569),
#  ('Terrence Howard', 7.292687),
#  ('Cillian Murphy', 7.812282999999999),
#  ('Li Bingbing', 6.253452),
#  ('Tom Hanks', 6.619415500000001),
#  ('Kavita Patil', 9.408097),
#  ('Michael Caine', 11.8650926),
#  ('Jeremy Irons', 15.5576675),
#  ('Dave Franco', 6.742778),
#  ('Keira Knightley', 9.031057800000001),
#  ('Michael Fassbender', 14.187058333333335),
#  ('Bill Nighy', 7.919401666666666),
#  ('Shakira', 10.603307),
#  ('Jordan Nagai', 7.456567),
#  ('Valeria Cavalli', 19.591843),
#  ('Analeigh Tipton', 7.817199),
#  ('Mahershala Ali', 9.346346),
#  ('Miles Christopher Bakshi', 12.552571),
#  ('Aimee Teegarden', 25.052685),
#  ('Stanley Tucci', 41.241753333333335),
#  ('Eric Stonestreet', 6.668656),
#  ('Toby Kebbell', 6.9847304999999995),
#  ('Faran Tahir', 7.292687),
#  ('Clark Gregg', 7.873816),
#  ('Josh Gad', 33.14790375),
#  ('Bess Motta', 5.920723),
#  ('Giovanni Ribisi', 7.2840489999999996),
#  ('Martin Freeman', 9.1270195),
#  ('Josh Hutcherson', 7.3400229999999995),
#  ('Harrison Ford', 9.4244345),
#  ('Paul Giamatti', 8.141364),
#  ('Tom Hiddleston', 24.827057250000003),
#  ('Zoey Deutch', 16.928488),
#  ('Dakota Johnson', 16.529983),
#  ('Liam Neeson', 6.77571975),
#  ('Mark Wahlberg', 7.2816855),
#  ('Jessica Barth', 5.813984),
#  ('Orlando Bloom', 7.935851857142857),
#  ('Jennifer Lawrence', 9.850007999999999),
#  ('Kristoffer Joner', 8.547333),
#  ('Haley Bennett', 6.502827),
#  ('Will Smith', 9.5666685),
#  ('Jamie Dornan', 16.529983),
#  ('Kaya Scodelario', 7.376165),
#  ('John Hurt', 5.783461),
#  ('Angeliki Papoulia', 5.872569),
#  ('Alicia Vikander', 6.002825333333334),
#  ('Theo James', 7.8148135000000005),
#  ('Michael Douglas', 6.971403),
#  ('Jon Hamm', 11.594164),
#  ('Holt McCallany', 7.165021),
#  ("Chris O'Dowd", 18.57872),
#  ('Keegan-Michael Key', 10.908939666666669),
#  ('Mackenzie Foy', 28.708868),
#  ('Liam Hemsworth', 7.3400229999999995),
#  ('Zachary Levi', 6.929765),
#  ('Stephen Root', 9.0461165),
#  ('Olga Dihovichnaya', 14.802872),
#  ('Zooey Deschanel', 6.967698),
#  ('Carrie Fisher', 9.4244345),
#  ('Scott Adsit', 9.883617),
#  ('Bruce Willis', 6.3501735),
#  ('Katie Holmes', 7.213378),
#  ('Eric Stoltz', 6.318769),
#  ('Josh Brolin', 6.381578),
#  ('Michelle Rodriguez', 8.351397),
#  ('Sam Claflin', 7.540051),
#  ("Lupita Nyong'o", 6.496464),
#  ('Don Cheadle', 22.28523),
#  ('Karl Urban', 6.093466),
#  ('Bill Paxton', 6.846971666666666),
#  ('Douglas Booth', 8.405976),
#  ('Michael Nyqvist', 24.011375),
#  ('Arnold Schwarzenegger', 8.140716),
#  ('Benedict Cumberbatch', 19.0753975),
#  ('Dougray Scott', 7.988016),
#  ('Giancarlo Esposito', 5.987531),
#  ('Robbie Coltrane', 7.558342),
#  ('Gwyneth Paltrow', 6.4948805),
#  ('Adam James', 19.591843),
#  ('Kevin McNally', 8.63878375),
#  ('Ben Kingsley', 6.339340999999999),
#  ('Irrfan Khan', 28.1021815),
#  ('William Fichtner', 8.688794),
#  ('Mark Ruffalo', 7.860366333333334),
#  ('Kevin Kline', 58.735904),
#  ('Nick Robinson', 49.354436),
#  ('Tyrese Gibson', 7.94868),
#  ('Judy Greer', 7.583209999999999),
#  ('Christopher Eccleston', 6.929765),
#  ('Bruce Willis', 6.3501735),
#  ('Linda Hamilton', 6.010781),
#  ('James McAvoy', 15.322437666666666),
#  ('Leonardo DiCaprio', 7.607153),
#  ('Miles Teller', 8.345908),
#  ('Samuel L. Jackson', 22.800518200000003),
#  ('Geoffrey Rush', 9.2601184),
#  ('Jennifer Lawrence', 9.850007999999999),
#  ('Michael Pitt', 9.064142),
#  ('Richard Madden', 6.255993),
#  ('Philip Seymour Hoffman', 7.3400229999999995),
#  ('Blake Jenner', 6.83872),
#  ('Laurence Fishburne', 10.30624775),
#  ('Anya Taylor-Joy', 24.261434),
#  ('Toby Kebbell', 6.9847304999999995),
#  ('Evangeline Lilly', 6.971403),
#  ('Emilia Clarke', 12.400586),
#  ('Michael Sheen', 11.841623),
#  ('Stephen Graham', 7.540051),
#  ('Tyler Perry', 9.102218),
#  ('Jack Davenport', 9.815410499999999),
#  ('Alan Tudyk', 9.083302999999999),
#  ('Mark Hamill', 9.4244345),
#  ('Kate Winslet', 7.805908333333334),
#  ('Sonoya Mizuno', 5.887713),
#  ('Ashton Sanders', 9.346346),
#  ('Kim Dickens', 9.102218),
#  ("Mark O'Brien", 30.521758),
#  ('Brad William Henke', 19.263882000000002),
#  ('Jared Leto', 9.1780605),
#  ('Chow Yun-fat', 7.800176),
#  ('Rooney Mara', 6.961866),
#  ('Kaare Kroppan', 6.205629),
#  ('Alan Ritchson', 8.688794),
#  ('Justin Timberlake', 6.967698),
#  ('Riz Ahmed', 6.961840499999999),
#  ('Bill Irwin', 28.708868),
#  ('Gina Rodriguez', 5.966517),
#  ('Nicholas Hoult', 20.1076065),
#  ('James Corden', 6.967698),
#  ('Leonardo DiCaprio', 7.607153),
#  ('Scott Speedman', 8.309146),
#  ('Shailene Woodley', 8.788518333333334),
#  ('Denis Leary', 7.7800585),
#  ('Judd Lormand', 8.192746),
#  ('Tom Hardy', 13.032542),
#  ('Christopher Walken', 6.496464),
#  ('Ansel Elgort', 7.8148135000000005),
#  ('Neel Sethi', 6.496464),
#  ('Luke Grimes', 16.529983),
#  ('Anna Paquin', 9.358546),
#  ('Amy Ryan', 8.096078),
#  ('Ian Holm', 5.783461),
#  ('Kate Winslet', 7.805908333333334),
#  ('Divian Ladwa', 6.961866),
#  ('Theo James', 7.8148135000000005),
#  ('Kevin McNally', 8.63878375),
#  ('Autumn Reeser', 6.388904),
#  ('Boyd Holbrook', 81.4974675),
#  ('Gina Carano', 16.097749),
#  ('Idina Menzel', 7.563299),
#  ('Anne Hathaway', 18.006317499999998),
#  ('Nina Dobrev', 9.305658),
#  ('Morgan Freeman', 7.150341999999999),
#  ('Kathryn Hahn', 8.749586),
#  ('Bruce McGill', 5.719267),
#  ('Blake Cooper', 8.756701),
#  ('Michael Caine', 11.8650926),
#  ('Lee Pace', 22.684227),
#  ('David Wenham', 6.961866),
#  ('Cillian Murphy', 7.812282999999999),
#  ('Bruce Dawson', 6.969082),
#  ('Lisa Kudrow', 9.527699),
#  ('Paul Reiser', 7.569539),
#  ('James Cromwell', 9.883617),
#  ('Anthony Mackie', 14.628316499999999),
#  ('Ian McShane', 13.503913666666667),
#  ('Anton Starkman', 7.048745),
#  ('Moran Atias', 19.591843),
#  ('Julia Stiles', 5.7055),
#  ('Mickey Rourke', 6.381578),
#  ('Ben Kingsley', 6.339340999999999),
#  ('Robby Benson', 58.735904),
#  ('Jennifer Aniston', 7.855861),
#  ('Ian McKellen', 7.7979484),
#  ("Dylan O'Brien", 6.903583),
#  ('Scarlett Johansson', 10.416892666666667),
#  ('Gretchen Mol', 7.017372),
#  ('Chris Evans', 13.041183666666667),
#  ('Daisy Ridley', 10.981076),
#  ('Gwen Stefani', 6.967698),
#  ('Steve Buscemi', 9.508472000000001),
#  ('Jordan Peele', 7.048745),
#  ('Dev Patel', 7.2127195),
#  ('Anthony Daniels', 7.867793),
#  ('Rosamund Pike', 9.102218),
#  ('Aaron Eckhart', 7.872788),
#  ('50 Cent', 6.736218),
#  ('Famke Janssen', 7.988016),
#  ('Michael Fassbender', 14.187058333333335),
#  ('Brianna Hildebrand', 16.097749),
#  ('Josh Gad', 33.14790375),
#  ('T.J. Miller', 11.548114333333332),
#  ('Scarlett Johansson', 10.416892666666667),
#  ('Ato Essandoh', 5.7055),
#  ('Claire Selby', 5.887713),
#  ('Simon Pegg', 6.6846745),
#  ('Michael Caine', 11.8650926),
#  ('Brad William Henke', 19.263882000000002),
#  ('Carla Gugino', 8.141364),
#  ('Kristen Wiig', 7.150002499999999),
#  ('Leslie Uggams', 16.097749),
#  ('Edward Norton', 7.566706666666668),
#  ('Will Poulter', 8.652017),
#  ('Jay Hernandez', 11.442708),
#  ('Travis Fimmel', 5.774444),
#  ('Jerry Orbach', 58.735904),
#  ('Yannick Bisson', 6.969082),
#  ('Yolandi Visser', 7.463573),
#  ('Tom Wilkinson', 8.974653),
#  ('Chris Evans', 13.041183666666667),
#  ('Lili Taylor', 5.987531),
#  ('Jeff Bridges', 6.853975),
#  ('Cristian Solimeno', 19.591843),
#  ('Armie Hammer', 10.112654),
#  ('Michael Kenneth Williams', 20.855296),
#  ('Marcia Gay Harden', 5.981202),
#  ('Keanu Reeves', 13.200742333333332),
#  ('Sigourney Weaver', 6.933032249999999),
#  ('Rachel McAdams', 17.426675),
#  ('Hayley Atwell', 6.255993),
#  ('James Badge Dale', 5.7201),
#  ('Courtney B. Vance', 8.662977),
#  ('Julianne Moore', 7.457081666666666),
#  ("Vincent D'Onofrio", 26.708796000000003),
#  ('Helena Bonham Carter', 6.584703),
#  ('Forest Whitaker', 15.081997333333334),
#  ('Johnny Depp', 8.4710622),
#  ('Robert Downey Jr.', 11.6040595),
#  ('Tom Hiddleston', 24.827057250000003),
#  ('Seth MacFarlane', 5.813984),
#  ('Mads Mikkelsen', 28.117132),
#  ('Michael Caine', 11.8650926),
#  ('Keri Russell', 8.195017),
#  ('Megan Mullally', 16.928488),
#  ('Maggie Grace', 7.988016),
#  ('Richard Armitage', 9.1270195),
#  ('Alan Tudyk', 9.083302999999999),
#  ('Megan Fox', 8.688794),
#  ('Ansel Elgort', 7.8148135000000005),
#  ("Dylan O'Brien", 6.903583),
#  ('Johnny Depp', 8.4710622),
#  ('Emma Watson', 33.00573275),
#  ('Kathy Bates', 6.591753),
#  ('Claudia Wells', 6.98611),
#  ('Joel Kinnaman', 8.580987499999999),
#  ('Jessica Sula', 24.261434),
#  ('Lewis Black', 7.076405),
#  ('John Rhys-Davies', 6.911901),
#  ('Sean Astin', 6.197896),
#  ('Jason Bateman', 9.633142),
#  ('Donald Sutherland', 10.104705),
#  ('James Nesbitt', 12.236899),
#  ('Bonnie Morgan', 25.052685),
#  ('Betty Buckley', 24.261434),
#  ('J.K. Simmons', 10.282945499999999),
#  ('Gloria Foster', 6.630537),
#  ('Logan Lerman', 14.26633),
#  ('Forest Whitaker', 15.081997333333334),
#  ('Juliette Binoche', 9.064142),
#  ('Jennifer Lawrence', 9.850007999999999),
#  ('Jared Leto', 9.1780605),
#  ('Adrianne Palicki', 24.011375),
#  ('Bob Gunton', 7.474345),
#  ('Joel Kinnaman', 8.580987499999999),
#  ('Laura Linney', 6.388904),
#  ('Jamie Foxx', 6.878338),
#  ('Allison Janney', 11.07952225),
#  ('Amy Poehler', 7.076405),
#  ('Ariyon Bakare', 14.802872),
#  ('Aurora Perrineau', 15.3741),
#  ('Jonathan Pryce', 11.981938),
#  ('Robert Duvall', 5.798605),
#  ('Rosemarie DeWitt', 8.001106),
#  ('Teddy Newton', 5.813134),
#  ('Rachael Harris', 6.035925),
#  ('Sidse Babett Knudsen', 6.849927),
#  ('Tom Hiddleston', 24.827057250000003),
#  ('Naomi Watts', 7.908568333333334),
#  ('Christian Bale', 7.957939),
#  ('Woody Harrelson', 7.120313400000001),
#  ('Tom Hardy', 13.032542),
#  ('Jason Clarke', 10.2978015),
#  ('Carrie Fisher', 9.4244345),
#  ('Abigail Hargrove', 5.7201),
#  ('Keegan-Michael Key', 10.908939666666669),
#  ('Kelsey Grammer', 7.048745),
#  ('Chris Hemsworth', 11.061846166666667),
#  ('Luke Grimes', 16.529983),
#  ('T.J. Miller', 11.548114333333332),
#  ('Jennifer Aniston', 7.855861),
#  ('Delroy Lindo', 7.456567),
#  ('Oscar Isaac', 9.738707333333332),
#  ('Bella Heathcote', 27.078764),
#  ('Jamie Chung', 9.883617),
#  ('Miranda Frigon', 6.969082),
#  ('Billy Crystal', 6.464373),
#  ('Mary Tsoni', 5.872569),
#  ('Dan Stevens', 58.735904),
#  ('Hailee Steinfeld', 6.83872),
#  ('Common', 8.960315),
#  ('Willem Dafoe', 9.7977555),
#  ('John Leguizamo', 8.173477333333333),
#  ('Ben Affleck', 9.851348333333334),
#  ('Sean Bean', 7.953369500000001),
#  ('Jake Gyllenhaal', 9.96748125),
#  ('Stephen Merchant', 157.275668),
#  ('William Kircher', 12.236899),
#  ('Keith Stanfield', 9.807999),
#  ('Gloria Stuart', 6.591753),
#  ('Harry Dean Stanton', 5.783461),
#  ('Luke Evans', 41.32487833333334),
#  ('John Lithgow', 10.191788),
#  ('Neil Patrick Harris', 9.102218),
#  ('Kyra Sedgwick', 6.83872),
#  ('Iris Dohrn', 6.967698),
#  ('Christopher Plummer', 7.456567),
#  ('Hugh Jackman', 58.03259566666666),
#  ('Jeff Bridges', 6.853975),
#  ('Ray Romano', 7.7800585),
#  ('Caleb Landry Jones', 9.807999),
#  ('Robert Downey Jr.', 11.6040595),
#  ('Stanley Tucci', 41.241753333333335),
#  ('Dick Van Dyke', 6.035925),
#  ('Michael Caine', 11.8650926),
#  ('Morgan Freeman', 7.150341999999999),
#  ('Ben Stiller', 6.035925),
#  ('Willem Dafoe', 9.7977555),
#  ('Vin Diesel', 13.312855),
#  ('Al Pacino', 5.798605),
#  ('John Leguizamo', 8.173477333333333),
#  ('Chris Williams', 7.563299),
#  ('David Ogden Stiers', 58.735904),
#  ('Joe Pantoliano', 6.630537),
#  ('Sigourney Weaver', 6.933032249999999),
#  ('Rory Kinnear', 10.033663),
#  ('Ian McKellen', 7.7979484),
#  ('Liv Tyler', 6.911901),
#  ('Jon Bernthal', 12.229059),
#  ('Tom Hanks', 6.619415500000001),
#  ('Mila Kunis', 8.405976),
#  ('Ian McShane', 13.503913666666667),
#  ('Griffin Gluck', 16.928488),
#  ('Holt McCallany', 7.165021),
#  ('Richard S. Castellano', 5.798605),
#  ('Carrie-Anne Moss', 6.630537),
#  ('Natalie Portman', 7.4017905),
#  ('Johnny Knoxville', 8.688794),
#  ('Josh Helman', 27.86788),
#  ('Kevin Bacon', 11.092789),
#  ('Tzi Ma', 30.521758),
#  ('John Boyega', 10.981076),
#  ('Robert Downey Jr.', 11.6040595),
#  ('Andrew Garfield', 12.343599),
#  ('Jake Johnson', 49.354436),
#  ('Kate McKinnon', 7.63751),
#  ('Ralph Fiennes', 6.182218),
#  ('Tuppence Middleton', 8.405976),
#  ('Jennifer Lawrence', 9.850007999999999),
#  ('Naomi Watts', 7.908568333333334),
#  ('S. Epatha Merkerson', 6.100839),
#  ('Alicia Vikander', 6.002825333333334),
#  ('Ginnifer Goodwin', 10.603307),
#  ('Patrick Stewart', 157.275668),
#  ('Frank Welker', 6.253452),
#  ('Sean Bean', 7.953369500000001),
#  ('Kyle Chandler', 7.017372),
#  ('Jesse Eisenberg', 8.5014085),
#  ('James McAvoy', 15.322437666666666),
#  ('Naomi Watts', 7.908568333333334),
#  ('Bradley Cooper', 22.684227),
#  ('Anthony Mackie', 14.628316499999999),
#  ('Dominique Louis', 5.813134),
#  ("Dylan O'Brien", 6.903583),
#  ('Bradley Pierce', 58.735904),
#  ('Richard Roundtree', 5.697074),
#  ('Corey Stoll', 6.971403),
#  ('Emily Blunt', 6.502827),
#  ('Marion Cotillard', 12.190083666666666),
#  ('Oscar Isaac', 9.738707333333332),
#  ('Heath Ledger', 9.356672),
#  ('Ana Ularu', 6.849927),
#  ('Carina Ruude', 6.205629),
#  ('Gary Oldman', 7.812323000000001),
#  ('Benedict Wong', 28.117132),
#  ('Jenny Slate', 6.668656),
#  ('Ann Cusack', 8.218181),
#  ('Amr Waked', 7.817199),
#  ('Richard Armitage', 9.1270195),
#  ('Hugh Keays-Byrne', 27.86788),
#  ('Brad Pitt', 8.149229250000001),
#  ('Chin Han', 9.064142),
#  ('Zachary Quinto', 8.414697),
#  ('Lake Bell', 6.668656),
#  ('Steve Krikris', 5.872569),
#  ('Olivia Williams', 6.415263),
#  ('Miles Teller', 8.345908),
#  ('Halle Berry', 9.358546),
#  ('Robert Patrick', 6.100839),
#  ('Paula Patton', 5.774444),
#  ('Sebastian Stan', 22.28523),
#  ('Will Arnett', 8.688794),
#  ('Robert Kazinsky', 5.774444),
#  ('Oona Laurence', 6.736218),
#  ('Gwyneth Paltrow', 6.4948805),
#  ('Skylan Brooks', 6.736218),
#  ('Bob Peterson', 6.96047),
#  ('Queen Latifah', 7.275883),
#  ('Tom Hiddleston', 24.827057250000003),
#  ('Lisa Kudrow', 9.527699),
#  ('Jennifer Lawrence', 9.850007999999999),
#  ('Marcus Chong', 6.630537),
#  ('Matt Damon', 8.448865),
#  ('John Goodman', 8.778580999999999),
#  ('Mindy Kaling', 7.076405),
#  ('Anton Yelchin', 6.093466),
#  ('Elijah Wood', 6.911901),
#  ('Sam Worthington', 10.5488565),
#  ('Lea Thompson', 6.98611),
#  ('Keira Knightley', 9.031057800000001),
#  ('Damon Wayans Jr.', 9.883617),
#  ('Scarlett Johansson', 10.416892666666667),
#  ('John C. Reilly', 76.41363),
#  ('Jason Bateman', 9.633142),
#  ('Gary Oldman', 7.812323000000001),
#  ('Richard E. Grant', 157.275668),
#  ('Choi Min-sik', 7.817199),
#  ('Michael Fassbender', 14.187058333333335),
#  ('Alexander Gould', 7.642378),
#  ('Idris Elba', 8.549885499999998),
#  ('Kate Winslet', 7.805908333333334),
#  ('Adam Sandler', 7.556508),
#  ('Stephen Root', 9.0461165),
#  ('Malgorzata Gebel', 6.182218),
#  ('Joseph Gordon-Levitt', 8.20811525),
#  ('Naomie Harris', 7.924397666666668),
#  ('Jennifer Saunders', 11.594164),
#  ('Erwin Leder', 8.309146),
#  ('Eriq La Salle', 157.275668),
#  ('Bill Hader', 7.076405),
#  ('Tye Sheridan', 12.347333),
#  ('Aidan Gillen', 5.987531),
#  ('Kevin Rahm', 8.218181),
#  ('Kaya Scodelario', 7.376165),
#  ('Lance Henriksen', 5.825851999999999),
#  ('Rebecca Ferguson', 10.6528495),
#  ('Olivia Munn', 8.662977),
#  ('Keanu Reeves', 13.200742333333332),
#  ('Abhishek Bharate', 6.961866),
#  ('Haley Lu Richardson', 15.550077000000002),
#  ('Sebastian Arcelus', 24.261434),
#  ('Andy Lau', 11.953133),
#  ('Patrick Heusinger', 8.192746),
#  ('Eric Johnson', 27.078764),
#  ('Zhang Hanyu', 11.953133),
#  ('Richard Kind', 7.076405),
#  ('Brad Carter', 8.547333),
#  ('Hugo Johnstone-Burt', 8.141364),
#  ('Marion Cotillard', 12.190083666666666),
#  ('Ashley Benson', 7.556508),
#  ('Rupert Grint', 7.2755615),
#  ('Archie Panjabi', 8.141364),
#  ('Alec Baldwin', 12.552571),
#  ('Jennifer Lawrence', 9.850007999999999),
#  ('Paul Rudd', 6.971403),
#  ('Julian Rhind-Tutt', 7.817199),
#  ('Jason Statham', 7.94868),
#  ('Ben Foster', 6.3121855),
#  ('Holliday Grainger', 6.255993),
#  ('Hugo Weaving', 9.487068),
#  ('Uma Thurman', 6.318769),
#  ('Andrea Riseborough', 8.096078),
#  ('Ariane Labed', 20.855296),
#  ('Gugu Mbatha-Raw', 8.405976),
#  ('Shailene Woodley', 8.788518333333334),
#  ('Cobie Smulders', 8.192746),
#  ('Phyllis Smith', 7.076405),
#  ('Anthony Hopkins', 7.4017905),
#  ('Margot Robbie', 11.442708),
#  ('Brie Larson', 76.41363),
#  ('Michael Biehn', 5.825851999999999),
#  ('Jesse Eisenberg', 8.5014085),
#  ('Zoe Saldana', 12.510602333333333),
#  ('Noel Fisher', 8.688794),
#  ('Hugh Laurie', 8.749586),
#  ('Neil Casey', 6.612043),
#  ('Tom Hardy', 13.032542),
#  ('Jai Courtney', 11.921647),
#  ('Eloise Mumford', 16.529983),
#  ('Dennis Christopher', 6.878338),
#  ('Hayden Szeto', 6.83872),
#  ('Thomas Robinson', 8.749586),
#  ('Lance Henriksen', 5.825851999999999),
#  ('Rosie Huntington-Whiteley', 27.86788),
#  ('Nicholas Hoult', 20.1076065),
#  ('Jon Voight', 43.012848),
#  ('Angela Lansbury', 58.735904),
#  ('Keanu Reeves', 13.200742333333332),
#  ('Leonardo DiCaprio', 7.607153),
#  ('Matthew Beard', 10.033663),
#  ('Ron Perlman', 43.012848),
#  ('Ryan Reynolds', 15.4503105),
#  ('Kaitlyn Dias', 7.076405),
#  ('John Malkovich', 5.966517),
#  ('J.K. Simmons', 10.282945499999999),
#  ('Laurence Fishburne', 10.30624775),
#  ('Veronica Cartwright', 5.783461),
#  ('Scott Eastwood', 10.735928),
#  ('Marion Cotillard', 12.190083666666666),
#  ('Earl Boen', 6.010781),
#  ('Alexander Calvert', 6.83872),
#  ('Casey Affleck', 17.86312),
#  ('Daniel Radcliffe', 7.2755615),
#  ('Leslie Bibb', 7.292687),
#  ('Paul Anderson', 8.547333),
#  ('Eddie Peng', 11.953133),
#  ('Viola Davis', 11.442708),
#  ('Tony Jaa', 9.305658),
#  ('Walton Goggins', 6.878338),
#  ('Ki Hong Lee', 8.756701),
#  ('Omar Sy', 6.849927),
#  ('Ninja', 7.463573),
#  ('Melissa Benoist', 10.250443),
#  ('Mireille Enos', 5.7201),
#  ('Bill Nighy', 7.919401666666666),
#  ('Orlando Bloom', 7.935851857142857),
#  ('Ben Barnes', 6.415263),
#  ('Johnny Depp', 8.4710622),
#  ('Daniel Kaluuya', 9.807999),
#  ('Nicola Peltz', 6.253452),
#  ('Channing Tatum', 8.405976),
#  ('Holly Hunter', 5.813134),
#  ('Orlando Bloom', 7.935851857142857),
#  ('David Thewlis', 6.992781),
#  ('J.K. Simmons', 10.282945499999999),
#  ('Hiroyuki Sanada', 14.802872),
#  ('Woody Harrelson', 7.120313400000001),
#  ('Colin Farrell', 43.012848),
#  ('Eddie Redmayne', 25.709412),
#  ('Jennifer Ehle', 5.981202),
#  ('Charlotte Rampling', 20.855296),
#  ('Melissa Leo', 10.735928),
#  ('Michael Rooker', 22.684227),
#  ('Emma Stone', 8.048592),
#  ("Vincent D'Onofrio", 26.708796000000003),
#  ('Dayo Okeniyi', 12.400586),
#  ('Elizabeth Banks', 5.957682),
#  ('Samuel L. Jackson', 22.800518200000003),
#  ('Melissa Benoist', 10.250443),
#  ('Alfie Allen', 24.011375),
#  ('Martin Freeman', 9.1270195),
#  ('Ed Skrein', 16.097749),
#  ('Brad Pitt', 8.149229250000001),
#  ('Woody Harrelson', 7.120313400000001),
#  ('John Leguizamo', 8.173477333333333),
#  ('Dakota Johnson', 16.529983),
#  ('Ruby Rose', 9.1329865),
#  ('Candace Cameron Bure', 6.969082),
#  ('Shia LaBeouf', 14.26633),
#  ('Rosario Dawson', 6.381578),
#  ('Julianne Moore', 7.457081666666666),
#  ('Paul Walker', 7.94868),
#  ('Jim Parrack', 14.26633),
#  ('Julee Cerda', 15.3741),
#  ('Lexa Doig', 6.969082),
#  ('Isla Fisher', 10.112654),
#  ('Jillian Bell', 8.662977),
#  ('Mark Hamill', 9.4244345),
#  ('Josh Hutcherson', 7.3400229999999995),
#  ('Barry Pepper', 5.987531),
#  ('Andy Serkis', 7.106078500000001),
#  ('Jordana Brewster', 7.94868),
#  ('Kaya Scodelario', 7.376165),
#  ('Jeremy Renner', 17.41132725),
#  ('Alicia Vikander', 6.002825333333334),
#  ('Liam Hemsworth', 7.3400229999999995),
#  ('Christoph Waltz', 6.878338),
#  ('Linda Hamilton', 6.010781),
#  ('Alan Rickman', 6.992781),
#  ('Ellen Page', 8.884867),
#  ('Jamie Dornan', 16.529983),
#  ('Liam Neeson', 6.77571975),
#  ('Shane Brolly', 8.309146),
#  ('Melissa McCarthy', 6.612043),
#  ('John C. McGinley', 5.697074),
#  ('Dev Patel', 7.2127195),
#  ('Lily James', 6.255993),
#  ('Johnny Depp', 8.4710622),
#  ('Matthew McConaughey', 28.708868),
#  ('Dwayne Johnson', 8.045022),
#  ('Liv Tyler', 6.911901),
#  ('Christopher Lee', 6.1959575000000005),
#  ('Dean Winters', 24.011375),
#  ('Aml Ameen', 8.756701),
#  ('Mark Rolston', 7.474345),
#  ('Thomas F. Wilson', 6.98611),
#  ('Kerry Washington', 6.878338),
#  ('Jean Smart', 10.191788),
#  ('Rene Russo', 8.218181),
#  ('Victor Rasuk', 5.981202),
#  ('Chris Hemsworth', 11.061846166666667),
#  ('Daniel Henney', 9.883617),
#  ('Anna Kalaitzidou', 5.872569),
#  ('Viggo Mortensen', 6.911901),
#  ('Laurence Fishburne', 10.30624775),
#  ('Javier Bardem', 7.384263),
#  ('John Ratzenberger', 7.456567),
#  ('Philip Seymour Hoffman', 7.3400229999999995),
#  ('Riccardo Scamarcio', 8.960315),
#  ('Morena Baccarin', 16.097749),
#  ('Liam Hemsworth', 7.3400229999999995),
#  ('Scarlett Johansson', 10.416892666666667),
#  ('Michelle Williams', 7.017372),
#  ('Brenton Thwaites', 7.384263),
#  ('Ewan McGregor', 58.735904),
#  ('James Spader', 8.747303),
#  ('Josh Hutcherson', 7.3400229999999995),
#  ('John Marley', 5.798605),
#  ('Peter Dinklage', 7.556508),
#  ('Zach Galifianakis', 8.096078),
#  ('Will Poulter', 8.652017),
#  ('Seann William Scott', 7.275883),
#  ('Holt McCallany', 7.165021),
#  ('Christos Stergioglou', 5.872569),
#  ('Santino Fontana', 7.563299),
#  ('Chris Pratt', 29.137587666666665),
#  ('Rupert Everett', 18.57872),
#  ('Maggie Q', 9.135343),
#  ('J.K. Simmons', 10.282945499999999),
#  ('John Cho', 6.093466),
#  ('Casey Affleck', 17.86312),
#  ('Jonny Weston', 6.494284),
#  ('Allison Janney', 11.07952225),
#  ('Edward Furlong', 6.100839),
#  ('James Caan', 5.798605),
#  ('Marilu Henner', 6.969082),
#  ('Tom Skerritt', 5.783461),
#  ('Richard Griffiths', 7.558342),
#  ('Viggo Mortensen', 6.911901),
#  ('Irrfan Khan', 28.1021815),
#  ('Thomas Brodie-Sangster', 7.372116),
#  ('Naomie Harris', 7.924397666666668),
#  ('Robin Williams', 6.035925),
#  ('Raffey Cassidy', 8.749586),
#  ('Amanda Seyfried', 5.813984),
#  ('Albert Brooks', 7.155517),
#  ('Jerome Ranft', 7.456567),
#  ('Sean Bean', 7.953369500000001),
#  ('Aaron Eckhart', 7.872788),
#  ('Bill Paxton', 6.846971666666666),
#  ('Simon Pegg', 6.6846745),
#  ('Bobby Moynihan', 6.668656),
#  ('James Franco', 16.928488),
#  ('Jake Gyllenhaal', 9.96748125),
#  ('Zoe Saldana', 12.510602333333333),
#  ('Anna Kendrick', 8.579743),
#  ('Chris Hemsworth', 11.061846166666667),
#  ('Pedro Pascal', 11.953133),
#  ('Amy Adams', 16.964817),
#  ('Kristen Bell', 7.563299),
#  ('Ed Asner', 7.456567),
#  ('Philip Seymour Hoffman', 7.3400229999999995),
#  ('Kenny Baker', 7.867793),
#  ('Morgan Freeman', 7.150341999999999),
#  ('Tate Donovan', 7.017372),
#  ('Jake Gyllenhaal', 9.96748125),
#  ('Embeth Davidtz', 6.182218),
#  ('Ian McKellen', 7.7979484),
#  ('Joseph Gordon-Levitt', 8.20811525),
#  ('Eli Fucile', 5.813134),
#  ('Gary Oldman', 7.812323000000001),
#  ('Philippe Leroy', 19.591843),
#  ('Jack Reynor', 6.253452),
#  ('Arnold Schwarzenegger', 8.140716),
#  ('John Cleese', 7.558342),
#  ('Robert Downey Jr.', 11.6040595),
#  ('Jeremy Renner', 17.41132725),
#  ('Giovanni Ribisi', 7.2840489999999996),
#  ('James Coburn', 6.464373),
#  ('Corey Johnson', 5.887713),
#  ('John Travolta', 6.318769),
#  ('Rebel Wilson', 6.035925),
#  ('Matt Damon', 8.448865),
#  ('Elijah Wood', 6.911901),
#  ('Michael Biehn', 5.825851999999999),
#  ('Camiel Warren-Taylor', 14.802872),
#  ('Chiwetel Ejiofor', 28.117132),
#  ('Finn Wittrock', 8.001106),
#  ('Sharlto Copley', 7.463573),
#  ('Zachary Quinto', 8.414697),
#  ('Goran Visnjic', 8.284234),
#  ('Elyes Gabel', 5.7201),
#  ('Rita Ora', 27.078764),
#  ('Woody Harrelson', 7.120313400000001),
#  ('Earl Boen', 6.010781),
#  ('Gary Oldman', 7.812323000000001),
#  ('Rila Fukushima', 9.064142),
#  ('Josh Peck', 7.275883),
#  ('Tilda Swinton', 28.117132),
#  ('Paul Reiser', 7.569539),
#  ('Zach Grenier', 6.913413),
#  ('Jessica Chastain', 18.198415),
#  ('Dan Fogler', 43.012848),
#  ('Christopher Lee', 6.1959575000000005),
#  ('Shailene Woodley', 8.788518333333334),
#  ('Sophia Myles', 7.281299000000001),
#  ('Gil Bellows', 7.474345),
#  ('Edward Norton', 7.566706666666668),
#  ('Michael Gambon', 6.992781),
#  ('Scarlett Johansson', 10.416892666666667),
#  ('Richard Harris', 7.558342),
#  ('Judi Dench', 18.57872),
#  ('Andy Serkis', 7.106078500000001),
#  ('Ian McKellen', 7.7979484),
#  ('Keira Knightley', 9.031057800000001),
#  ('Jeremy Renner', 17.41132725),
#  ('Vin Diesel', 13.312855),
#  ('Octavia Spencer', 10.603307),
#  ('Marlon Brando', 5.798605),
#  ('Idris Elba', 8.549885499999998),
#  ('Luke Evans', 41.32487833333334),
#  ('Chris Pine', 6.093466),
#  ('Don Harvey', 7.988016),
#  ('Christian Bale', 7.957939),
#  ('Joseph Gordon-Levitt', 8.20811525),
#  ('Grethe Ryen', 6.205629),
#  ('Michael Sheen', 11.841623),
#  ('Charles Dance', 8.322853),
#  ('Matt Damon', 8.448865),
#  ('Mark Ruffalo', 7.860366333333334),
#  ('Thomas Brodie-Sangster', 7.372116),
#  ('Austin Pendleton', 7.642378),
#  ('Ben Schnetzer', 5.774444),
#  ('Morgan Freeman', 7.150341999999999),
#  ('Hugo Weaving', 9.487068),
#  ('Steffen Rothschild', 6.205629),
#  ('Jeremy Renner', 17.41132725),
#  ('Tim Robbins', 7.474345),
#  ('Luke Bracey', 12.343599),
#  ('Samuel L. Jackson', 22.800518200000003),
#  ('Amy Adams', 16.964817),
#  ('Ken Stott', 12.236899),
#  ('John Rhys-Davies', 6.911901),
#  ('Hugh Jackman', 58.03259566666666),
#  ('Bradley Whitford', 9.807999),
#  ('Cate Blanchett', 6.136566500000001),
#  ('Carrie Coon', 9.102218),
#  ('Zoe Saldana', 12.510602333333333),
#  ('Anna Gunn', 6.388904),
#  ('Oscar Isaac', 9.738707333333332),
#  ('Kristen Wiig', 7.150002499999999),
#  ('Steve Buscemi', 9.508472000000001),
#  ('Teresa Palmer', 12.343599),
#  ('Kate Mara', 7.687962),
#  ('Trevante Rhodes', 9.346346),
#  ('Rami Malek', 6.035925),
#  ('Frances Fisher', 6.591753),
#  ('Jon Bernthal', 12.229059),
#  ('Anne Hathaway', 18.006317499999998),
#  ('Jonathan Groff', 7.563299),
#  ('Hristos Passalis', 5.872569),
#  ('Terry Notary', 76.41363),
#  ('Steve Coogan', 11.594164),
#  ('Nicole Kidman', 6.961866),
#  ('Sam Spruell', 7.988016),
#  ('Ty Simpkins', 49.354436),
#  ('Tobey Maguire', 12.552571),
#  ('Nathan Jones', 27.86788),
#  ('Britt Robertson', 8.749586),
#  ('Sam Worthington', 10.5488565),
#  ('Geoffrey Rush', 9.2601184),
#  ('Clancy Brown', 7.474345),
#  ('Rachel McAdams', 17.426675),
#  ('Elizabeth Banks', 5.957682),
#  ('Judy Greer', 7.583209999999999),
#  ('Jeff Daniels', 7.687962),
#  ('Ellie Bamber', 10.112654),
#  ('Sophie McShera', 6.255993),
#  ('Ellen Page', 8.884867),
#  ('Geoffrey Rush', 9.2601184),
#  ('Bill Murray', 6.496464),
#  ('R. Lee Ermey', 5.697074),
#  ('Paul Winfield', 5.920723),
#  ('Leonardo DiCaprio', 7.607153),
#  ('Bill Paxton', 6.846971666666666),
#  ('Christian Bale', 7.957939),
#  ('Johnny Galecki', 25.052685),
#  ('Anne-Lise Tangstad', 6.205629),
#  ('Lucas Hedges', 7.017372),
#  ('Alison Sudol', 43.012848),
#  ('Emma Watson', 33.00573275),
#  ('Henry Cavill', 10.260039),
#  ('Kevin James', 7.556508),
#  ('James McAvoy', 15.322437666666666),
#  ('Pete Ploszek', 8.688794),
#  ('Naomie Harris', 7.924397666666668),
#  ('Matilda Anna Ingrid Lutz', 25.052685),
#  ('Joe Morton', 6.100839),
#  ('Mary Gibbs', 6.464373),
#  ('J.K. Simmons', 10.282945499999999),
#  ('Bobby Cannavale', 6.971403),
#  ('Ray Romano', 7.7800585),
#  ('Deepika Padukone', 9.305658),
#  ('Bridget Moynahan', 24.011375),
#  ('Jason Mitchell', 76.41363),
#  ('Riz Ahmed', 6.961840499999999),
#  ('Ryan Reynolds', 15.4503105),
#  ('Geoffrey Rush', 9.2601184),
#  ('Christopher Lloyd', 6.98611),
#  ('Jharrel Jerome', 9.346346),
#  ('Domhnall Gleeson', 7.217523),
#  ('Chris Pratt', 29.137587666666665),
#  ('Rachel Griffiths', 12.343599),
#  ('Richard White', 58.735904),
#  ('Chris Hemsworth', 11.061846166666667),
#  ('Morgan Freeman', 7.150341999999999),
#  ("Vincent D'Onofrio", 26.708796000000003),
#  ('Matt Smith', 12.400586),
#  ('Michael J. Fox', 6.98611),
#  ('Keegan-Michael Key', 10.908939666666669),
#  ('Danika Yarosh', 8.192746),
#  ('Caroline Goodall', 6.182218),
#  ('Ryan Gosling', 8.001106),
#  ('Callie Hernandez', 8.001106),
#  ('Keira Knightley', 9.031057800000001),
#  ('Daria Nicolodi', 19.591843),
#  ('Michelle Monaghan', 9.3246485),
#  ('Lenny Kravitz', 6.064087),
#  ('Brad Pitt', 8.149229250000001),
#  ('Viggo Mortensen', 6.911901),
#  ('Vin Diesel', 13.312855),
#  ('Amy Adams', 16.964817),
#  ('Kevin McNally', 8.63878375),
#  ('Sean Bean', 7.953369500000001),
#  ('Emma Watson', 33.00573275),
#  ('Vivi Ann Yee', 12.552571),
#  ('Michael Stuhlbarg', 30.521758),
#  ('Jack Black', 8.284234),
#  ('Orlando Bloom', 7.935851857142857),
#  ('Anthony Hopkins', 7.4017905),
#  ('Diane Lane', 10.260039),
#  ('Vince Vaughn', 12.343599),
#  ('Katie Crown', 7.048745),
#  ('Ken Watanabe', 8.411188),
#  ('Ioan Gruffudd', 8.141364),
#  ('Johnny Depp', 8.4710622),
#  ('William Hope', 5.730981),
#  ('Janelle Monae', 9.346346),
#  ('Liam Neeson', 6.77571975),
#  ('Alec Guinness', 7.867793),
#  ('J.K. Simmons', 10.282945499999999),
#  ('Maggie Gyllenhaal', 9.356672),
#  ('Mark Wahlberg', 7.2816855),
#  ('Bill Nighy', 7.919401666666666),
#  ('Ellen DeGeneres', 7.642378),
#  ('Mark Ruffalo', 7.860366333333334),
#  ('Jeffrey Tambor', 10.191788),
#  ('Jack Davenport', 9.815410499999999),
#  ('Charles Dance', 8.322853),
#  ('Tom Hardy', 13.032542),
#  ('Dave Bautista', 22.684227),
#  ('Harrison Ford', 9.4244345),
#  ('David Andrews', 5.7201),
#  ('Jeremy Irons', 15.5576675),
#  ('Chris Pratt', 29.137587666666665),
#  ('Orlando Bloom', 7.935851857142857),
#  ('Orlando Bloom', 7.935851857142857),
#  ('Rose Byrne', 12.347333),
#  ('Chris Hemsworth', 11.061846166666667),
#  ('Elijah Wood', 6.911901),
#  ('T.J. Miller', 11.548114333333332),
#  ('Michael Keaton', 9.845120999999999),
#  ('Jaimie Alexander', 6.929765),
#  ('Jonathan Sagall', 6.182218),
#  ('Michael Beach', 11.092789),
#  ('Sophia Myles', 7.281299000000001),
#  ('Michael Hyatt', 8.218181),
#  ('Jai Courtney', 11.921647),
#  ('Takeshi Kitano', 9.064142),
#  ('Samuel L. Jackson', 22.800518200000003),
#  ('Haley Lu Richardson', 15.550077000000002),
#  ('Peter Cushing', 7.867793),
#  ('Laura Wiggins', 25.052685),
#  ('Marc McClure', 6.98611),
#  ('Jimmy Kimmel', 12.552571),
#  ('Crispin Glover', 6.98611),
#  ('Yaphet Kotto', 5.783461),
#  ('Jose Pablo Cantillo', 7.463573),
#  ('Ben Foster', 6.3121855),
#  ('Boyd Holbrook', 81.4974675),
#  ('David Maldonado', 5.966517),
#  ('Craig T. Nelson', 5.813134),
#  ('Forest Whitaker', 15.081997333333334),
#  ('Bryan Cranston', 16.928488),
#  ('Kevin McNally', 8.63878375),
#  ('Brad Pitt', 8.149229250000001),
#  ('Djimon Hounsou', 6.415263),
#  ('Graham McTavish', 12.236899),
#  ('Cate Blanchett', 6.136566500000001),
#  ('Samuel L. Jackson', 22.800518200000003),
#  ('Morgan Freeman', 7.150341999999999),
#  ("Mike O'Malley", 6.388904),
#  ('Kris Wu', 9.305658),
#  ('Leslie Jones', 6.612043),
#  ('Kate McKinnon', 7.63751),
#  ('Sterling Hayden', 5.798605),
#  ('Ed Harris', 5.719267),
#  ('Ryan Potter', 9.883617),
#  ('Corey Hawkins', 76.41363),
#  ('John Legend', 8.001106),
#  ('Benedict Cumberbatch', 19.0753975),
#  ('Kate Beckinsale', 8.309146),
#  ('Sterling Jerins', 5.7201),
#  ('Russell Brand', 6.967698),
#  ('Meat Loaf', 6.913413),
#  ('Donnie Yen', 9.305658),
#  ('Rupert Grint', 7.2755615),
#  ('C.J. Wilson', 7.017372),
#  ('Alex Roe', 25.052685),
#  ('Billy Zane', 6.591753),
#  ('Ving Rhames', 6.318769),
#  ('Keira Knightley', 9.031057800000001),
#  ('Felicity Jones', 6.849927),
#  ('Michelle Rodriguez', 8.351397),
#  ('Jennifer Tilly', 6.464373),
#  ('Daniel Radcliffe', 7.2755615),
#  ('Katherine Waterston', 43.012848),
#  ('Brendan Gleeson', 20.855296),
#  ('Domhnall Gleeson', 7.217523),
#  ('Eloise Mumford', 16.529983),
#  ('Owen Wilson', 6.035925),
#  ('Lizzy Caplan', 6.742778),
#  ('Eva Green', 12.480149),
#  ('Kit Harington', 6.415263),
#  ('Stephen Lang', 8.754114),
#  ('Jake Gyllenhaal', 9.96748125),
#  ('Austin Stowell', 9.408097),
#  ('Rebecca Ferguson', 10.6528495),
#  ("Paige O'Hara", 58.735904),
#  ('Denis Leary', 7.7800585),
#  ('Logan Marshall-Green', 10.735928),
#  ('Sam J. Jones', 5.813984),
#  ('Bob Peterson', 6.96047),
#  ('George Clooney', 8.749586),
#  ('Kevin Hart', 6.668656),
#  ('Kurt Russell', 5.966517),
#  ('Catherine Keener', 9.807999),
#  ('Michelle Monaghan', 9.3246485),
#  ('Chris Hemsworth', 11.061846166666667),
#  ('Asia Argento', 19.591843),
#  ('Will Smith', 9.5666685),
#  ('Eva Green', 12.480149),
#  ('Jayson Blair', 9.408097),
#  ('Alexandra Daddario', 8.141364),
#  ('Aaron Taylor-Johnson', 10.112654),
#  ('Woody Harrelson', 7.120313400000001),
#  ('Jessica Chastain', 18.198415),
#  ('Ian McShane', 13.503913666666667),
#  ('Vincent Cassel', 5.7055),
#  ('Scarlett Johansson', 10.416892666666667),
#  ('Bryce Dallas Howard', 49.354436),
#  ('Dominic Cooper', 5.774444),
#  ('Sunny Pawar', 6.961866),
#  ('Joel David Moore', 8.754114),
#  ('Sylvester McCoy', 6.01714),
#  ('Liam Neeson', 6.77571975),
#  ('Kodi Smit-McPhee', 8.195017),
#  ('Jason Lee', 5.813134),
#  ('Harvey Keitel', 6.318769),
#  ('Laurence Fishburne', 10.30624775),
#  ('Liv Tyler', 6.911901),
#  ('Albert Brooks', 7.155517),
#  ('Kate Hudson', 5.966517),
#  ('Jessica Alba', 6.381578),
#  ('Chris Evans', 13.041183666666667),
#  ('Asa Butterfield', 18.57872),
#  ('Adam Driver', 10.981076),
#  ('Helena Bonham Carter', 6.584703),
#  ('Michael Shannon', 10.112654),
#  ('Tom Cruise', 8.192746),
#  ('Julianne Moore', 7.457081666666666),
#  ('Gary Oldman', 7.812323000000001),
#  ('James Whitmore', 7.474345),
#  ('Orlando Bloom', 7.935851857142857),
#  ('Tommy Lee Jones', 5.7055),
#  ('Andy Samberg', 7.048745),
#  ('Helen Mirren', 7.690629),
#  ...]
